# %%
! nvidia-smi
# Out:
# Wed Sep 21 15:52:05 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # path for loading data

# %%
# using Google drive path'

# 코랩을 이용하지 않을 경우 필요하지 않음.
from google.colab import drive
drive.mount('/content/drive')

# path 넣어주기
x_path = 'drive/MyDrive/X_data.npy'
x_2d_path = 'drive/MyDrive/X_2d_data.npy'
y_path = 'drive/MyDrive/Y_data.npy'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import libraries, Set device

# %%
# import libraries
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import numpy as np
import random
import torch.nn.functional as F
import sklearn.metrics as metrics
import os 
from torchvision.models import resnet18
import torchvision.transforms.functional as f

# set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# for reproducibility
def seed(seed = 1):
    random.seed(seed)
    np.random.seed(seed) 
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic=True
    os.environ["PYTHONHASHSEED"] = str(seed)

seed(42)

g = torch.Generator()
g.manual_seed(42)

# %% [markdown]
# # functions for data preprocessing

# %%
def get_0_164_ind(tensor, threshold):
    """code for removing data containing missing values, not used.
    """
    ind_0_164 = []
    for i in range(tensor.shape[0]):
        ind_0_cnt = (tensor[i, :] == 0.0).sum()
        ind_164_cnt = (tensor[i, :] == 164.0).sum()
        nvalue_cnt = ind_0_cnt + ind_164_cnt
        if nvalue_cnt.item() == 0:
            ind_0_164.append(i)  
    return ind_0_164

def dropNaN(X, Y):
    """drop data without target label
    """
    drop_ind = Y == -1
    return np.delete(X, drop_ind, axis=0), np.delete(Y, drop_ind)

def Normalization(X):
    """for data normalization
    """
    X_mean = X.mean(dim=1)
    X_std = X.std(dim=1)
    temp = np.zeros_like(X)
    for i in range(X.shape[0]):
        temp[i, :] = (X[i, :] - X_mean[i]) / X_std[i]
    return torch.Tensor(temp)

def one_hot(Y):
    """for one-hot encoding
    """
    Y_hot = np.zeros((len(Y), 3))
    for i, d in enumerate(Y):
        Y_hot[i, int(d)-1] = 1
    return torch.Tensor(Y_hot)

# %% [markdown]
# # loading data

# %%
X = torch.FloatTensor(np.load(x_path))
X_2d = torch.FloatTensor(np.load(x_2d_path))
Y = np.load(y_path)

# %% [markdown]
# # data preprocessing
# - drop unlabeled data
# - Normalization (only 1d since 2d data's values are in [0, 1])
# - one hot encoding
# - data split
# - data augmentation (considered, but unused)

# %%
# drop data without target label
X_2d, _ = dropNaN(X_2d, Y)
X, Y = dropNaN(X, Y)
X_2d = X_2d / 255
X_2d = f.normalize(X_2d, [0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
# Normalization
X = Normalization(X)

all_X, all_Y = X, Y  # for test 1d vs 2d

# target value ratio
print(f'label 1: {100*(Y==1).sum()/len(Y):.3f}%, label 2: {100*(Y==2).sum()/len(Y):.3f}%, label 3: {100*(Y==3).sum()/len(Y):.3f}%\n')

# one hot encoding
Y = one_hot(Y)
print(f'X size : {X.size()}\n')
print(f'Y size : {Y.size()}\n')

# data split with ratio 8 : 2
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=1, stratify=Y)

# data augmentation, not used
"""
add_ind = Y_train.argmax(dim=1) != 2
X_train = torch.cat( (X_train, X_train[add_ind, :]), dim=0)
Y_train = np.concatenate( (Y_train, Y_train[add_ind, :]))
"""

# train, test 
print(f'Train set 개수: {X_train.shape[0]}개\n')
print(f'Test set 개수: {X_test.shape[0]}개\n')

for i in range(3):
    print(f'label {i}: {100*(Y_train.argmax(axis=1)==i).sum()/len(Y_train):.3f}%')
# Out:
# label 1: 8.048%, label 2: 8.646%, label 3: 83.306%
#
# X size : torch.Size([1839, 4192])
#
# Y size : torch.Size([1839, 3])
#
# Train set 개수: 1471개
#
# Test set 개수: 368개
#
# label 0: 8.022%
# label 1: 8.634%
# label 2: 83.345%

# %% [markdown]
# # Dataset, Dataloader for training 1d resnet
# - only for train, not used for 1d vs 2d

# %%
# Dataset, DataLoader 
class Dset(Dataset):
    def __init__(self, x_data, y_data):
        super(Dset, self).__init__()
        self.x = x_data
        self.y = y_data
    
    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]
    
    def __len__(self):
        return len(self.x)
    
train_dset = Dset(X_train, Y_train)
train_dataloader = DataLoader(train_dset, batch_size=32, shuffle=True, generator=g)

test_dset = Dset(X_test, Y_test)
test_dataloader = DataLoader(test_dset, batch_size=len(test_dset), shuffle=False, generator=g)

# %% [markdown]
# # Early stopping class
# - only for train, not used for 1d vs 2d
# - used to prevent overfitting

# %%
# 조기 종료 클래스
class EarlyStopping:
    """주어진 patience 이후로 validation loss가 개선되지 않으면 학습을 조기 중지"""
    def __init__(self, patience=7, verbose=False, delta=0, path='checkpoint.pt', save=True):
        """
        Args:
            patience (int): validation loss가 개선된 후 기다리는 기간
                            Default: 7
            verbose (bool): True일 경우 각 validation loss의 개선 사항 메세지 출력
                            Default: False
            delta (float): 개선되었다고 인정되는 monitered quantity의 최소 변화
                            Default: 0
            path (str): checkpoint저장 경로
                            Default: 'checkpoint.pt'
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.save = save

    def __call__(self, val_loss, model, global_best_accuracy, mode='Min'):
        if mode == 'Min':
            score = -val_loss
        else:
            score = val_loss
        if self.best_score is None:
            self.best_score = score
            if val_loss > global_best_accuracy:
                self.save_checkpoint(val_loss, model)
            else:
                print('점수는 나아졌으나 전체 모델 점수보단 덜함.')
        elif score < self.best_score + self.delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            if val_loss > global_best_accuracy:
                self.save_checkpoint(val_loss, model)
            else:
                print('점수는 나아졌으나 전체 모델 점수보단 덜함.')
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''validation loss가 감소하면 모델을 저장한다.'''
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        if self.save:
            torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %% [markdown]
# # 1D CNN Model
# - It is not used because the resnet model has better performance.

# %%
class cnn_1d(nn.Module):
    def __init__(self):
        super(cnn_1d, self).__init__()
        self.activation = nn.ReLU()
        self.layer1 = nn.Sequential(  
                         nn.Conv1d(1, 128, kernel_size=7, stride=1, bias=True, padding=3),   # (B, 128, 4192)
                         self.activation,
                         nn.Dropout(0.4),
                         nn.Conv1d(128, 64, kernel_size=3, stride=1, bias=True, padding=1),  # (B, 16, 4192)
                         self.activation,
                         nn.Dropout(0.3),
                         nn.Conv1d(64, 32, kernel_size=3, stride=1, bias=True, padding=1),  # (B, 8, 4192)
                         self.activation,
                         nn.Dropout(0.3),
                         nn.Conv1d(32, 128, kernel_size=3, stride=1, bias=True, padding=1)  
        )  
        self.flat = nn.Flatten()
        self.layer2 = nn.Sequential(
                         nn.Linear(536576, 512, bias=True),
                         self.activation,
                         nn.Dropout(0.3),
                         nn.Linear(512, 256, bias=True),
                         self.activation,
                         nn.Linear(256, 128, bias=True),
                         self.activation,
                         nn.Dropout(0.3),
                         nn.Linear(128, 32, bias=True),
                         self.activation,
                         nn.BatchNorm1d(32),
                         nn.Dropout(0.3),
                         nn.Linear(32, 3, bias=True)
                         #nn.Softmax(dim=1)
        )
        # self.test = nn.Conv1d(1, 128, kernel_size=1)

    
    def forward(self, x):
        out = self.layer1(x)
        out = F.relu(out)
        out = self.flat(out)
        out = self.layer2(out)
        return out

model = cnn_1d()
t = torch.zeros((2, 1, 4192))
t = model(t)
print(t)
del t
# Out:
# tensor([[ 0.1945, -1.1080,  0.4560],
#         [ 0.1058,  0.6208,  0.1074]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# # 1D ResNet18
# - actual structure is slightly different from ResNet18 since I made it myself, and the input size & dimension is different.

# %%
class Block_B(nn.Module):
    def __init__(self):
        super(Block_B, self).__init__()
        self.layer = nn.Sequential(
            nn.Conv1d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Conv1d(64, 64, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU()
    ) 

    def forward(self, x):
        return self.layer(x)

class Block_C(nn.Module):
    def __init__(self, input_size):
        super(Block_C, self).__init__()
        self.layer = nn.Sequential(
            nn.Conv1d(input_size, 128, kernel_size=3, stride=1, padding=1),  # 28 * 28
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Conv1d(128, 128, kernel_size=3, stride=1, padding=1),  # 28 * 28
            nn.BatchNorm1d(128),
            nn.ReLU()
    ) 

    def forward(self, x):
        return self.layer(x)

class Block_D(nn.Module):
    def __init__(self, input_size):
        super(Block_D, self).__init__()
        self.layer = nn.Sequential(
            nn.Conv1d(input_size, 256, kernel_size=3, stride=1, padding=1),  # 28 * 28
            nn.BatchNorm1d(256),
            nn.ReLU(),
            nn.Conv1d(256, 256, kernel_size=3, stride=1, padding=1),  # 28 * 28
            nn.BatchNorm1d(256),
            nn.ReLU()
    ) 

    def forward(self, x):
        return self.layer(x)       

class Block_E(nn.Module):
    def __init__(self, input_size):
        super(Block_E, self).__init__()
        self.layer = nn.Sequential(
            nn.Conv1d(input_size, 512, kernel_size=3, stride=1, padding=1),  # 28 * 28
            nn.BatchNorm1d(512),
            nn.ReLU(),
            nn.Conv1d(512, 512, kernel_size=3, stride=1, padding=1),  # 28 * 28
            nn.BatchNorm1d(512),
            nn.ReLU()
    ) 

    def forward(self, x):
        return self.layer(x)  

class Resnet1d(nn.Module):  # inpurt (B, 1, 4192)
    def __init__(self):
        super(Resnet1d, self).__init__()
        self.Block_A = nn.Sequential(
                nn.Conv1d(1, 64, kernel_size=8, stride=2, padding=3),  # (64, 2096)
                nn.BatchNorm1d(64),
                nn.ReLU(),
                nn.MaxPool1d(3, 2, 1)  # 절반으로 만드는 layer
        )  # (B, 64, 1048)
        self.Block_B_1 = Block_B()
        self.Block_B_2 = Block_B()


        self.Block_C_1 = Block_C(64)
        self.Block_C_2 = Block_C(128)
        self.conv1x1_C = nn.Conv1d(64, 128, kernel_size=1, stride=1, padding=0)

        self.Block_D_1 = Block_D(128)
        self.Block_D_2 = Block_D(256)
        self.conv1x1_D = nn.Conv1d(128, 256, kernel_size=1, stride=1, padding=0)

        self.Block_E_1 = Block_E(256)
        self.Block_E_2 = Block_E(512)
        self.conv1x1_E = nn.Conv1d(256, 512, kernel_size=1, stride=1, padding=0)

        self.fc_layer = nn.Sequential(
              nn.AdaptiveAvgPool1d(7),
              nn.Flatten(),
              nn.Linear(3584, 3)
        )
    def forward(self, x):
      out = self.Block_A(x)

      out = F.relu(self.Block_B_1(out) + out)
      out = F.relu(self.Block_B_2(out) + out)
      out = F.max_pool1d(out, 3, 2, 1)

      out = F.relu(self.Block_C_1(out) + self.conv1x1_C(out))
      out = F.relu(self.Block_C_2(out) + out)
      out = F.max_pool1d(out, 3, 2, 1)

      out = F.relu(self.Block_D_1(out) + self.conv1x1_D(out))
      out = F.relu(self.Block_D_2(out) + out)
      out = F.max_pool1d(out, 3, 2, 1)

      out = F.relu(self.Block_E_1(out) + self.conv1x1_E(out))

      out = F.relu(self.Block_E_2(out) + out)
      out = F.max_pool1d(out, 3, 2, 1)

      out = self.fc_layer(out)
      
      return out

# test
t = torch.zeros((1, 1, 4192))

res = Resnet1d()

print(res(t))
# Out:
# tensor([[-0.2307, -0.8111, -0.0020]], grad_fn=<AddmmBackward0>)

# %% [markdown]
# # functions & variables for 1D vs 2D

# %%
# for grid search
batch_size_grid = [8]*3 + [16]*3 + [32]*3
batch_size_grid *= 2
lr_grid = [1e-5, 1e-4, 1e-3]*6
dim_grid = ['1D']*9 + ['2D']*9
grid_list = zip(batch_size_grid, lr_grid, dim_grid)

# for KFold
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits = 5)

skf.get_n_splits(all_X, all_Y)

def train_test_with_index(X, Y, test_ind):
    train_ind = list(set(range(len(Y))) - set(test_ind))
    return X[train_ind], X[test_ind], Y[train_ind], Y[test_ind]

# Data Recording Array



arr_name_list = ['accuracy_epoch_50', 'accuracy_epoch_100', 'accuracy_max',
                 'sensitivity_epoch_50', 'sensitivity_epoch_100', 'sensitivity_max',
                 'specificity_epoch_50', 'specificity_epoch_100', 'specificity_max']

def dim_model_select(dim):
    if dim == '1D':
        model = Resnet1d()
    else:
        model = resnet18(pretrained=True)
        model.fc = nn.Linear(in_features = 512, out_features = 3)
        model.to(device)
    return model

def one_hot_to_binary(arr):
    temp = arr[:, :2].argmax(dim=1).reshape(-1, 1)
    return torch.Tensor(np.concatenate((temp, arr[:, 2].reshape(-1, 1)), axis=1))

def save_arr(*arrays):
    for i, arr in enumerate(arrays):
        np.save(f'drive/MyDrive/temp_arrays/{arr_name_list[i]}.npy', arr)

# %% [markdown]
# # For test 1d vs 2d
# - 1d data : extracted time series data
# - 2d data : 2d cropped data with 3 channel (RGB)
# - 1d model : 1d resnet18 (not pretrained)
# - 2d model : 2d resnet18 bulit in torchvision (pretrained)
#
# > Since there is not enough data, use 5 fold (8 : 2)
#
#
# - hyperparameters:
#         batch_size = {8, 16, 32},
#         learning_rate = {1e-3, 1e-4, 1e-5}
#         dimension = {'1D', '2D'}
#         (3*3*2 = 18 combinations)
#
# - recording features at each fold + average of 5 fold
#         accuracy at 50 epoch, 100 epoch, largest value in entire epoch
#         sensitivity at 50 epoch, 100 epoch, largest value in entire epoch
#         specificity at 50 epoch, 100 epoch, largest value in entire epoch

# %%
all_Y_onehot = one_hot(all_Y)  
recorded_cnt = 0 # change this to skip recorded cnt
current_cnt = 0

if recorded_cnt == -1:
    accuracy_epoch_50 = np.zeros((18, 6))  # 18 grid search / 5 fold, avg
    accuracy_epoch_100 = np.zeros((18, 6))
    accuracy_max = np.zeros((18, 6))

    sensitivity_epoch_50 = np.zeros((18, 6))  # 18 grid search / 5 fold, avg
    sensitivity_epoch_100 = np.zeros((18, 6))
    sensitivity_max = np.zeros((18, 6))

    specificity_epoch_50 = np.zeros((18, 6))  # 18 grid search / 5 fold, avg
    specificity_epoch_100 = np.zeros((18, 6))
    specificity_max = np.zeros((18, 6))
else:
    accuracy_epoch_50 = np.load('drive/MyDrive/temp_arrays/accuracy_epoch_50.npy')  # 18 grid search / 5 fold, avg
    accuracy_epoch_100 = np.load('drive/MyDrive/temp_arrays/accuracy_epoch_100.npy')
    accuracy_max = np.load('drive/MyDrive/temp_arrays/accuracy_max.npy')

    sensitivity_epoch_50 = np.load('drive/MyDrive/temp_arrays/sensitivity_epoch_50.npy')  # 18 grid search / 5 fold, avg
    sensitivity_epoch_100 = np.load('drive/MyDrive/temp_arrays/sensitivity_epoch_100.npy')
    sensitivity_max = np.load('drive/MyDrive/temp_arrays/sensitivity_max.npy')

    specificity_epoch_50 = np.load('drive/MyDrive/temp_arrays/specificity_epoch_50.npy')  # 18 grid search / 5 fold, avg
    specificity_epoch_100 = np.load('drive/MyDrive/temp_arrays/specificity_epoch_100.npy')
    specificity_max = np.load('drive/MyDrive/temp_arrays/specificity_max.npy')

grid_list = zip(batch_size_grid, lr_grid, dim_grid)
for batch_size, lr, dim in grid_list:
    if current_cnt <= recorded_cnt:
        print(batch_size, lr, dim)
        current_cnt += 1
        continue
    print(f'lr: {lr}, batch_size: {batch_size}, dim: {dim}, cnt: {current_cnt}')
    fold = -1
    for _, test_index in skf.split(all_X, all_Y):
        print(f'fold {fold+1}')
        fold += 1
        X_in = X if dim == '1D' else X_2d
        X_train, X_test, Y_train, Y_test = train_test_with_index(X_in, 
                                                    all_Y_onehot, test_index)
        X_train = X_train.to(device)
        X_test = X_test.to(device)
        Y_train = Y_train.to(device)
        Y_test = Y_test.to(device)
        model = dim_model_select(dim).to(device)
        
        optimizer = torch.optim.Adam(model.parameters(), lr=lr)

        train_dset = Dset(X_train, Y_train)
        test_dset = Dset(X_test, Y_test)
        train_dataloader = DataLoader(train_dset, batch_size=batch_size, 
                                      shuffle=True)   
        test_dataloader = DataLoader(test_dset, batch_size=len(test_dset), 
                                     shuffle=False)   
        max_accuracy, max_sensitivity, max_specificity  = 0, 0, 0

        # Train with current fold
        for epoch in range(1, 101):
            model.train()
            print(f'epoch {epoch}', end=' ')
            for x_batch, y_batch in train_dataloader:
                if dim == '1D':
                    x_batch = x_batch.unsqueeze(1).to(device)
                y_batch = y_batch.to(device)
                criterion = model(x_batch)
                cost = F.cross_entropy(criterion, y_batch)
                optimizer.zero_grad()
                cost.backward()
                optimizer.step()
                del x_batch, y_batch
                torch.cuda.empty_cache()
            
            print('\n'+'-'*20)

            print(f'cost={cost.item()}')

            # Val set test
            model.eval()
            with torch.no_grad():
                for x_batch, y_batch in test_dataloader:
                    if dim == '1D':
                        x_batch = x_batch.unsqueeze(1).to(device)
                    y_batch = y_batch.to(device)
                    test_criterion = model(x_batch)
                    test_cost = F.cross_entropy(test_criterion, y_batch)
                    print(f'test cost={test_cost.item()}')
                    acc = sum(test_criterion.argmax(dim=1) == y_batch.argmax(dim=1)) / len(test_dset)
                    print(f'test accurary={100*acc.item()}%')
                    y_batch = y_batch.to('cpu')
                    y_batch = one_hot_to_binary(y_batch)
                    test_criterion = test_criterion.to('cpu')
                    test_criterion = one_hot_to_binary(test_criterion)
                    tp, fn, fp, tn = metrics.confusion_matrix(y_batch.argmax(dim=1), test_criterion.argmax(dim=1)).ravel()
                    specificity = tn / (tn + fp)
                    print(tn, fp, fn, tp)
                    sensitivity = tp / (tp + fn)
                    print(f'specificity={specificity:.2f}, sensitivity={sensitivity:.2f}')
                    del x_batch, y_batch
                    torch.cuda.empty_cache()
                
                # recording data
                accuracy_max[current_cnt, fold] = max(accuracy_max[current_cnt, fold], acc)
                sensitivity_max[current_cnt, fold] = max(sensitivity_max[current_cnt, fold], sensitivity)
                specificity_max[current_cnt, fold] = max(specificity_max[current_cnt, fold], specificity)

                if epoch == 50:
                    accuracy_epoch_50[current_cnt, fold] = acc
                    sensitivity_epoch_50[current_cnt, fold] = sensitivity
                    specificity_epoch_50[current_cnt, fold] = specificity
                
                if epoch == 100:
                    accuracy_epoch_100[current_cnt, fold] = acc
                    sensitivity_epoch_100[current_cnt, fold] = sensitivity
                    specificity_epoch_100[current_cnt, fold] = specificity
                torch.cuda.empty_cache()
             
        save_arr(accuracy_epoch_50, 
                accuracy_epoch_100, 
                accuracy_max,
                sensitivity_epoch_50,
                sensitivity_epoch_100, 
                sensitivity_max,
                specificity_epoch_50,
                specificity_epoch_100,
                specificity_max)

    print(f'recorded_cnt = {current_cnt}')
    current_cnt += 1
# Out:
# 8 1e-05 1D
# lr: 0.0001, batch_size: 8, dim: 1D, cnt: 1
# fold 0
# epoch 1
# --------------------
# cost=0.16430625319480896
# test cost=0.5788634419441223
# test accurary=77.71739363670349%
# 306 1 58 3
# specificity=1.00, sensitivity=0.05
# epoch 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-b8d4fb9d6509> in <module>
#      72                 optimizer.step()
#      73                 del x_batch, y_batch
# ---> 74                 torch.cuda.empty_cache()
#      75
#      76             print('\n'+'-'*20)
#
# /usr/local/lib/python3.7/dist-packages/torch/cuda/memory.py in empty_cache()
#     119     """
#     120     if is_initialized():
# --> 121         torch._C._cuda_emptyCache()
#     122
#     123
#
# KeyboardInterrupt:

# %% [markdown]
# 이 아래부터는 1d vs 2d가 아닌, 1d resnet 학습을 목적으로 함.

# %%
# Train 
total_best_accuracy = 0
best_train_score = []
best_test_score = []
best_test_accuracy = []

for lr, batch_size in zip(random_learning_rate, random_batch_size):
    print(f'lr: {lr}, batch_size={batch_size}')
    model_best_accuracy=0
    torch.cuda.empty_cache()
    model = Resnet1d().to(device)
    early_stopping = EarlyStopping(patience=30, verbose = True)
    train_score = []
    test_score = []
    test_accuracy = []
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    train_dataloader = DataLoader(train_dset, batch_size=batch_size, shuffle=True)   
    for epoch in range(2000):
        model.train()
        cnt = 0
        print(f'epoch {epoch+1}', end=' ')
        for x_batch, y_batch in train_dataloader:
            cnt+=1
            x_batch = x_batch.unsqueeze(1).to(device)
            y_batch = y_batch.to(device)
            # print(x_batch.size())
            criterion = model(x_batch)
            # print(criterion.size())
            # weight = torch.Tensor([13, 13, 1]).to(device)
            # weight = torch.Tensor([4, 4, 1]).to(device)
            cost = F.cross_entropy(criterion, y_batch) # , weight=weight)
            optimizer.zero_grad()
            cost.backward()
            optimizer.step()
            del x_batch
            del y_batch
            # del weight
            torch.cuda.empty_cache()
        
        print('\n'+'-'*20)
        print(f'cost={cost.item()}')
        train_score.append(cost.item())
        model.eval()

        with torch.no_grad():
            for x_batch, y_batch in test_dataloader:
                x_batch = x_batch.unsqueeze(1).to(device)
                y_batch = y_batch.to(device)
                test_criterion = model(x_batch)
                
                test_cost = F.cross_entropy(test_criterion, y_batch)
                print(f'test cost={test_cost.item()}')

                acc = sum(test_criterion.argmax(dim=1) == y_batch.argmax(dim=1)) / len(test_dset)
                print(f'test accurary={100*acc.item()}%')
                print(f'ratio: {(test_criterion.argmax(dim=1) == 0).sum()} : {(test_criterion.argmax(dim=1) == 1).sum()} : {(test_criterion.argmax(dim=1) == 2).sum()}')
                del x_batch
                del y_batch
                torch.cuda.empty_cache()
            test_score.append(test_cost.item())
            test_accuracy.append(100*acc.item())
            if acc > model_best_accuracy:
                model_best_accuracy = acc
            print('-'*20)
            model.to('cpu')
            early_stopping(acc.item(), model, total_best_accuracy, mode='Max')
            model.to('cuda')
            if early_stopping.early_stop:
                if model_best_accuracy > total_best_accuracy:
                    total_best_accuracy = model_best_accuracy
                    best_train_score = train_score[:]
                    best_test_score = test_score[:]
                    best_test_accuracy = test_accuracy[:]
                    print(f'lr: {lr}, batch_size={batch_size} is best')
                print(f"Early stopping, current best acc:{total_best_accuracy}")
                break
            torch.cuda.empty_cache()
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# test accurary=93.76218318939209%
# ratio: 37 : 38 : 438
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 71
# --------------------
# cost=0.008539258502423763
# test cost=0.22200907766819
# test accurary=92.98245906829834%
# ratio: 37 : 35 : 441
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 72
# --------------------
# cost=0.009263938292860985
# test cost=0.2283133864402771
# test accurary=93.37232112884521%
# ratio: 35 : 36 : 442
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 73
# --------------------
# cost=0.014207495376467705
# test cost=0.21400326490402222
# test accurary=93.76218318939209%
# ratio: 38 : 37 : 438
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 74
# --------------------
# cost=0.003216516925022006
# test cost=0.23291786015033722
# test accurary=93.17739009857178%
# ratio: 37 : 34 : 442
# --------------------
# EarlyStopping counter: 11 out of 30
# epoch 75
# --------------------
# cost=0.0020321772899478674
# test cost=0.23209863901138306
# test accurary=93.95711421966553%
# ratio: 33 : 36 : 444
# --------------------
# EarlyStopping counter: 12 out of 30
# epoch 76
# --------------------
# cost=0.006133737042546272
# test cost=0.24185670912265778
# test accurary=93.56725215911865%
# ratio: 32 : 33 : 448
# --------------------
# EarlyStopping counter: 13 out of 30
# epoch 77
# --------------------
# cost=0.030082199722528458
# test cost=0.24373920261859894
# test accurary=93.17739009857178%
# ratio: 31 : 32 : 450
# --------------------
# EarlyStopping counter: 14 out of 30
# epoch 78
# --------------------
# cost=0.0017853097524493933
# test cost=0.24903982877731323
# test accurary=93.17739009857178%
# ratio: 33 : 32 : 448
# --------------------
# EarlyStopping counter: 15 out of 30
# epoch 79
# --------------------
# cost=0.006012376397848129
# test cost=0.30434656143188477
# test accurary=92.20272898674011%
# ratio: 32 : 24 : 457
# --------------------
# EarlyStopping counter: 16 out of 30
# epoch 80
# --------------------
# cost=0.009871155023574829
# test cost=0.2276843637228012
# test accurary=93.56725215911865%
# ratio: 40 : 54 : 419
# --------------------
# EarlyStopping counter: 17 out of 30
# epoch 81
# --------------------
# cost=0.0017494934145361185
# test cost=0.23458273708820343
# test accurary=92.98245906829834%
# ratio: 36 : 34 : 443
# --------------------
# EarlyStopping counter: 18 out of 30
# epoch 82
# --------------------
# cost=0.0017491369508206844
# test cost=0.25255098938941956
# test accurary=93.76218318939209%
# ratio: 32 : 34 : 447
# --------------------
# EarlyStopping counter: 19 out of 30
# epoch 83
# --------------------
# cost=0.0016779487486928701
# test cost=0.2152058333158493
# test accurary=93.95711421966553%
# ratio: 38 : 40 : 435
# --------------------
# EarlyStopping counter: 20 out of 30
# epoch 84
# --------------------
# cost=0.0019693817012012005
# test cost=0.2410692721605301
# test accurary=93.95711421966553%
# ratio: 32 : 35 : 446
# --------------------
# EarlyStopping counter: 21 out of 30
# epoch 85
# --------------------
# cost=0.004437992349267006
# test cost=0.25560587644577026
# test accurary=92.59259104728699%
# ratio: 45 : 35 : 433
# --------------------
# EarlyStopping counter: 22 out of 30
# epoch 86
# --------------------
# cost=0.02029675804078579
# test cost=0.23958991467952728
# test accurary=94.15204524993896%
# ratio: 32 : 36 : 445
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 87
# --------------------
# cost=0.013622891157865524
# test cost=0.21508347988128662
# test accurary=93.76218318939209%
# ratio: 38 : 40 : 435
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 88
# --------------------
# cost=0.0017444908153265715
# test cost=0.22634170949459076
# test accurary=93.95711421966553%
# ratio: 33 : 38 : 442
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 89
# --------------------
# cost=0.009535612538456917
# test cost=0.2366839498281479
# test accurary=92.98245906829834%
# ratio: 35 : 33 : 445
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 90
# --------------------
# cost=0.060889389365911484
# test cost=0.2712666094303131
# test accurary=92.98245906829834%
# ratio: 30 : 30 : 453
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 91
# --------------------
# cost=0.0032910937443375587
# test cost=0.26836246252059937
# test accurary=92.7875280380249%
# ratio: 30 : 31 : 452
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 92
# --------------------
# cost=0.001842858036980033
# test cost=0.249701127409935
# test accurary=93.37232112884521%
# ratio: 31 : 33 : 449
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 93
# --------------------
# cost=0.0007002655183896422
# test cost=0.2229558676481247
# test accurary=93.56725215911865%
# ratio: 37 : 36 : 440
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 94
# --------------------
# cost=0.0026187519542872906
# test cost=0.2263612151145935
# test accurary=93.76218318939209%
# ratio: 35 : 37 : 441
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 95
# --------------------
# cost=0.003702303161844611
# test cost=0.22098073363304138
# test accurary=93.95711421966553%
# ratio: 34 : 40 : 439
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 96
# --------------------
# cost=0.002822859212756157
# test cost=0.23241575062274933
# test accurary=93.95711421966553%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 97
# --------------------
# cost=0.0015115247806534171
# test cost=0.2497265636920929
# test accurary=93.95711421966553%
# ratio: 32 : 35 : 446
# --------------------
# EarlyStopping counter: 11 out of 30
# epoch 98
# --------------------
# cost=0.00426603015512228
# test cost=0.24119794368743896
# test accurary=93.76218318939209%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 12 out of 30
# epoch 99
# --------------------
# cost=0.019717827439308167
# test cost=0.2373063862323761
# test accurary=93.17739009857178%
# ratio: 35 : 34 : 444
# --------------------
# EarlyStopping counter: 13 out of 30
# epoch 100
# --------------------
# cost=0.0025360886938869953
# test cost=0.27655214071273804
# test accurary=93.37232112884521%
# ratio: 31 : 29 : 453
# --------------------
# EarlyStopping counter: 14 out of 30
# epoch 101
# --------------------
# cost=0.003530662041157484
# test cost=0.2230105847120285
# test accurary=94.15204524993896%
# ratio: 34 : 42 : 437
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 102
# --------------------
# cost=0.00334826298058033
# test cost=0.23233826458454132
# test accurary=94.15204524993896%
# ratio: 34 : 38 : 441
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 103
# --------------------
# cost=0.0013914521550759673
# test cost=0.21952122449874878
# test accurary=94.3469762802124%
# ratio: 33 : 38 : 442
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 104
# --------------------
# cost=0.010306216776371002
# test cost=0.22930555045604706
# test accurary=94.15204524993896%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 105
# --------------------
# cost=0.002018923405557871
# test cost=0.24571864306926727
# test accurary=93.95711421966553%
# ratio: 33 : 36 : 444
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 106
# --------------------
# cost=0.0010662514250725508
# test cost=0.23135459423065186
# test accurary=93.95711421966553%
# ratio: 34 : 37 : 442
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 107
# --------------------
# cost=0.0009709186269901693
# test cost=0.24895396828651428
# test accurary=93.37232112884521%
# ratio: 37 : 35 : 441
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 108
# --------------------
# cost=0.0016537070041522384
# test cost=0.2364499568939209
# test accurary=93.95711421966553%
# ratio: 33 : 36 : 444
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 109
# --------------------
# cost=0.0006413759547285736
# test cost=0.24131077527999878
# test accurary=94.15204524993896%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 110
# --------------------
# cost=0.0033079958520829678
# test cost=0.23513828217983246
# test accurary=94.54191327095032%
# ratio: 32 : 38 : 443
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 111
# --------------------
# cost=0.0009586004889570177
# test cost=0.24931912124156952
# test accurary=93.95711421966553%
# ratio: 33 : 36 : 444
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 112
# --------------------
# cost=0.04010207951068878
# test cost=0.2791031002998352
# test accurary=93.56725215911865%
# ratio: 33 : 34 : 446
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 113
# --------------------
# cost=0.0011667909566313028
# test cost=0.2574199140071869
# test accurary=94.15204524993896%
# ratio: 38 : 38 : 437
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 114
# --------------------
# cost=0.0012712517054751515
# test cost=0.25773414969444275
# test accurary=93.95711421966553%
# ratio: 36 : 35 : 442
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 115
# --------------------
# cost=0.000505433592479676
# test cost=0.24665039777755737
# test accurary=93.56725215911865%
# ratio: 36 : 35 : 442
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 116
# --------------------
# cost=0.000777150911744684
# test cost=0.2372117042541504
# test accurary=93.76218318939209%
# ratio: 36 : 38 : 439
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 117
# --------------------
# cost=0.010876800864934921
# test cost=0.24410556256771088
# test accurary=93.95711421966553%
# ratio: 36 : 35 : 442
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 118
# --------------------
# cost=0.016834750771522522
# test cost=0.2574494481086731
# test accurary=92.98245906829834%
# ratio: 34 : 32 : 447
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 119
# --------------------
# cost=0.046230100095272064
# test cost=0.35060906410217285
# test accurary=92.59259104728699%
# ratio: 31 : 25 : 457
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 120
# --------------------
# cost=0.6693811416625977
# test cost=0.3157365918159485
# test accurary=91.22806787490845%
# ratio: 36 : 29 : 448
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 121
# --------------------
# cost=0.026527415961027145
# test cost=0.2518162429332733
# test accurary=91.81286692619324%
# ratio: 32 : 54 : 427
# --------------------
# EarlyStopping counter: 11 out of 30
# epoch 122
# --------------------
# cost=0.007164196576923132
# test cost=0.23353087902069092
# test accurary=93.17739009857178%
# ratio: 38 : 37 : 438
# --------------------
# EarlyStopping counter: 12 out of 30
# epoch 123
# --------------------
# cost=0.004411244299262762
# test cost=0.21016524732112885
# test accurary=93.37232112884521%
# ratio: 39 : 41 : 433
# --------------------
# EarlyStopping counter: 13 out of 30
# epoch 124
# --------------------
# cost=0.004951378330588341
# test cost=0.22191062569618225
# test accurary=94.54191327095032%
# ratio: 34 : 40 : 439
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 125
# --------------------
# cost=0.01081936340779066
# test cost=0.21924379467964172
# test accurary=94.15204524993896%
# ratio: 36 : 38 : 439
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 126
# --------------------
# cost=0.015836652368307114
# test cost=0.2300553023815155
# test accurary=94.3469762802124%
# ratio: 34 : 37 : 442
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 127
# --------------------
# cost=0.0077276951633393764
# test cost=0.21832598745822906
# test accurary=93.56725215911865%
# ratio: 38 : 39 : 436
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 128
# --------------------
# cost=0.0019563171081244946
# test cost=0.2518450617790222
# test accurary=94.73684430122375%
# ratio: 34 : 35 : 444
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 129
# --------------------
# cost=0.0011088417377322912
# test cost=0.23174117505550385
# test accurary=94.15204524993896%
# ratio: 35 : 37 : 441
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 130
# --------------------
# cost=0.004168860614299774
# test cost=0.22672626376152039
# test accurary=93.95711421966553%
# ratio: 36 : 37 : 440
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 131
# --------------------
# cost=0.004246382974088192
# test cost=0.23720546066761017
# test accurary=94.3469762802124%
# ratio: 34 : 37 : 442
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 132
# --------------------
# cost=0.00279607018455863
# test cost=0.2316710501909256
# test accurary=94.54191327095032%
# ratio: 34 : 38 : 441
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 133
# --------------------
# cost=0.0017995190573856235
# test cost=0.22433261573314667
# test accurary=93.17739009857178%
# ratio: 41 : 40 : 432
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 134
# --------------------
# cost=0.0010261302813887596
# test cost=0.24022871255874634
# test accurary=94.15204524993896%
# ratio: 35 : 37 : 441
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 135
# --------------------
# cost=0.004845060408115387
# test cost=0.2361290156841278
# test accurary=94.3469762802124%
# ratio: 34 : 37 : 442
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 136
# --------------------
# cost=0.0026984594296664
# test cost=0.237142875790596
# test accurary=93.76218318939209%
# ratio: 37 : 37 : 439
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 137
# --------------------
# cost=0.28216472268104553
# test cost=0.2422402948141098
# test accurary=92.39766001701355%
# ratio: 43 : 55 : 415
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 138
# --------------------
# cost=0.006716471165418625
# test cost=0.41469186544418335
# test accurary=91.03313684463501%
# ratio: 30 : 16 : 467
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 139
# --------------------
# cost=0.0035160183906555176
# test cost=0.23362523317337036
# test accurary=94.73684430122375%
# ratio: 33 : 42 : 438
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 140
# --------------------
# cost=0.0027773124165832996
# test cost=0.22101454436779022
# test accurary=94.73684430122375%
# ratio: 34 : 43 : 436
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 141
# --------------------
# cost=0.008742759935557842
# test cost=0.24882791936397552
# test accurary=94.3469762802124%
# ratio: 33 : 34 : 446
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 142
# --------------------
# cost=0.012008721008896828
# test cost=0.24397802352905273
# test accurary=93.95711421966553%
# ratio: 33 : 44 : 436
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 143
# --------------------
# cost=0.006467134691774845
# test cost=0.2359800934791565
# test accurary=94.54191327095032%
# ratio: 33 : 39 : 441
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 144
# --------------------
# cost=0.0008634504629299045
# test cost=0.24353493750095367
# test accurary=94.15204524993896%
# ratio: 35 : 37 : 441
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 145
# --------------------
# cost=0.006733786314725876
# test cost=0.2348790019750595
# test accurary=93.95711421966553%
# ratio: 36 : 37 : 440
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 146
# --------------------
# cost=0.04686063528060913
# test cost=0.24945864081382751
# test accurary=94.3469762802124%
# ratio: 33 : 38 : 442
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 147
# --------------------
# cost=0.0013133231550455093
# test cost=0.22542895376682281
# test accurary=94.3469762802124%
# ratio: 36 : 43 : 434
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 148
# --------------------
# cost=0.002140538766980171
# test cost=0.2502458691596985
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 149
# --------------------
# cost=0.0010052553843706846
# test cost=0.2331332415342331
# test accurary=93.95711421966553%
# ratio: 36 : 37 : 440
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 150
# --------------------
# cost=0.0018222670769318938
# test cost=0.23272734880447388
# test accurary=94.15204524993896%
# ratio: 36 : 38 : 439
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 151
# --------------------
# cost=0.0003003650635946542
# test cost=0.24537016451358795
# test accurary=94.15204524993896%
# ratio: 35 : 37 : 441
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 152
# --------------------
# cost=0.002287577372044325
# test cost=0.23689121007919312
# test accurary=94.3469762802124%
# ratio: 36 : 39 : 438
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 153
# --------------------
# cost=0.002516345353797078
# test cost=0.23216553032398224
# test accurary=94.3469762802124%
# ratio: 36 : 39 : 438
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 154
# --------------------
# cost=0.0012203222140669823
# test cost=0.2385663539171219
# test accurary=94.3469762802124%
# ratio: 36 : 39 : 438
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 155
# --------------------
# cost=0.001571339787915349
# test cost=0.2510184347629547
# test accurary=94.3469762802124%
# ratio: 34 : 37 : 442
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 156
# --------------------
# cost=0.0008599500870332122
# test cost=0.23904666304588318
# test accurary=94.73684430122375%
# ratio: 33 : 38 : 442
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 157
# --------------------
# cost=0.0060498653911054134
# test cost=0.250450074672699
# test accurary=94.54191327095032%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 158
# --------------------
# cost=0.0033855363726615906
# test cost=0.2581280767917633
# test accurary=94.54191327095032%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 159
# --------------------
# cost=0.0007931145373731852
# test cost=0.26513874530792236
# test accurary=94.54191327095032%
# ratio: 32 : 36 : 445
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 160
# --------------------
# cost=0.0014416819903999567
# test cost=0.24875789880752563
# test accurary=94.15204524993896%
# ratio: 35 : 37 : 441
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 161
# --------------------
# cost=0.005445527844130993
# test cost=0.24510829150676727
# test accurary=94.54191327095032%
# ratio: 34 : 38 : 441
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 162
# --------------------
# cost=0.0006363342399708927
# test cost=0.24678818881511688
# test accurary=94.93177533149719%
# ratio: 32 : 38 : 443
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 163
# --------------------
# cost=0.0013030478730797768
# test cost=0.2552665174007416
# test accurary=94.93177533149719%
# ratio: 32 : 38 : 443
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 164
# --------------------
# cost=0.00042944130836986005
# test cost=0.24882948398590088
# test accurary=94.15204524993896%
# ratio: 34 : 36 : 443
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 165
# --------------------
# cost=0.0006556007429026067
# test cost=0.2455279529094696
# test accurary=94.54191327095032%
# ratio: 34 : 38 : 441
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 166
# --------------------
# cost=0.0006538567831739783
# test cost=0.2465183436870575
# test accurary=94.54191327095032%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 167
# --------------------
# cost=0.002416040515527129
# test cost=0.25153207778930664
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 168
# --------------------
# cost=0.0002094527444569394
# test cost=0.244279146194458
# test accurary=95.12670636177063%
# ratio: 32 : 39 : 442
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 169
# --------------------
# cost=0.0020989009644836187
# test cost=0.25679805874824524
# test accurary=94.54191327095032%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 170
# --------------------
# cost=0.0008642756147310138
# test cost=0.25728273391723633
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 171
# --------------------
# cost=0.0005377248162403703
# test cost=0.2532464563846588
# test accurary=94.15204524993896%
# ratio: 34 : 36 : 443
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 172
# --------------------
# cost=0.049683913588523865
# test cost=0.24058248102664948
# test accurary=94.3469762802124%
# ratio: 33 : 36 : 444
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 173
# --------------------
# cost=0.003310543019324541
# test cost=0.22860023379325867
# test accurary=94.15204524993896%
# ratio: 35 : 49 : 429
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 174
# --------------------
# cost=0.0018968632211908698
# test cost=0.2544651925563812
# test accurary=94.93177533149719%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 175
# --------------------
# cost=0.0019408243242651224
# test cost=0.23930421471595764
# test accurary=94.93177533149719%
# ratio: 35 : 37 : 441
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 176
# --------------------
# cost=0.0012630193959921598
# test cost=0.22488480806350708
# test accurary=94.93177533149719%
# ratio: 33 : 48 : 432
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 177
# --------------------
# cost=0.00023499663802795112
# test cost=0.24370713531970978
# test accurary=94.15204524993896%
# ratio: 33 : 41 : 439
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 178
# --------------------
# cost=0.00030587040237151086
# test cost=0.25338077545166016
# test accurary=94.54191327095032%
# ratio: 33 : 39 : 441
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 179
# --------------------
# cost=0.0002385474363109097
# test cost=0.2523343861103058
# test accurary=94.73684430122375%
# ratio: 33 : 38 : 442
# --------------------
# EarlyStopping counter: 11 out of 30
# epoch 180
# --------------------
# cost=0.000562758999876678
# test cost=0.25717246532440186
# test accurary=94.54191327095032%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 12 out of 30
# epoch 181
# --------------------
# cost=0.0004442562931217253
# test cost=0.2551864683628082
# test accurary=94.54191327095032%
# ratio: 34 : 36 : 443
# --------------------
# EarlyStopping counter: 13 out of 30
# epoch 182
# --------------------
# cost=0.001337225316092372
# test cost=0.2508070170879364
# test accurary=94.93177533149719%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 14 out of 30
# epoch 183
# --------------------
# cost=0.00029845055541954935
# test cost=0.254730761051178
# test accurary=94.54191327095032%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 15 out of 30
# epoch 184
# --------------------
# cost=0.00020639493595808744
# test cost=0.2639504075050354
# test accurary=94.54191327095032%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 16 out of 30
# epoch 185
# --------------------
# cost=0.0003934384440071881
# test cost=0.2553301155567169
# test accurary=94.54191327095032%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 17 out of 30
# epoch 186
# --------------------
# cost=0.0015333672054111958
# test cost=0.25169292092323303
# test accurary=94.3469762802124%
# ratio: 33 : 36 : 444
# --------------------
# EarlyStopping counter: 18 out of 30
# epoch 187
# --------------------
# cost=0.0027978362049907446
# test cost=0.26806640625
# test accurary=94.3469762802124%
# ratio: 31 : 36 : 446
# --------------------
# EarlyStopping counter: 19 out of 30
# epoch 188
# --------------------
# cost=0.0020185094326734543
# test cost=0.26249417662620544
# test accurary=94.54191327095032%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 20 out of 30
# epoch 189
# --------------------
# cost=0.0003840659046545625
# test cost=0.2486216127872467
# test accurary=94.54191327095032%
# ratio: 33 : 37 : 443
# --------------------
# EarlyStopping counter: 21 out of 30
# epoch 190
# --------------------
# cost=0.001842083758674562
# test cost=0.2627348005771637
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# EarlyStopping counter: 22 out of 30
# epoch 191
# --------------------
# cost=0.00019381113816052675
# test cost=0.2557711899280548
# test accurary=94.73684430122375%
# ratio: 33 : 36 : 444
# --------------------
# EarlyStopping counter: 23 out of 30
# epoch 192
# --------------------
# cost=0.006646421737968922
# test cost=0.2619057893753052
# test accurary=94.54191327095032%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 24 out of 30
# epoch 193
# --------------------
# cost=0.00034600598155520856
# test cost=0.25712159276008606
# test accurary=94.3469762802124%
# ratio: 33 : 36 : 444
# --------------------
# EarlyStopping counter: 25 out of 30
# epoch 194
# --------------------
# cost=0.00020630312792491168
# test cost=0.265517920255661
# test accurary=94.3469762802124%
# ratio: 33 : 36 : 444
# --------------------
# EarlyStopping counter: 26 out of 30
# epoch 195
# --------------------
# cost=0.0002836161875165999
# test cost=0.2538916766643524
# test accurary=94.54191327095032%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 27 out of 30
# epoch 196
# --------------------
# cost=0.000170349347172305
# test cost=0.2632720470428467
# test accurary=94.54191327095032%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 28 out of 30
# epoch 197
# --------------------
# cost=0.000710488180629909
# test cost=0.25161564350128174
# test accurary=93.95711421966553%
# ratio: 35 : 36 : 442
# --------------------
# EarlyStopping counter: 29 out of 30
# epoch 198
# --------------------
# cost=0.0012671075528487563
# test cost=0.2548650801181793
# test accurary=94.54191327095032%
# ratio: 33 : 35 : 445
# --------------------
# EarlyStopping counter: 30 out of 30
# Early stopping, current best acc:0.9688109159469604
# lr: 0.0003992687731985774, batch_size=32
# epoch 1
# --------------------
# cost=0.7966926097869873
# test cost=0.5605166554450989
# test accurary=79.72709536552429%
# ratio: 29 : 41 : 443
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 2
# --------------------
# cost=1.4581639766693115
# test cost=0.548711359500885
# test accurary=76.60818696022034%
# ratio: 66 : 95 : 352
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 3
# --------------------
# cost=2.8463592529296875
# test cost=0.8912954330444336
# test accurary=60.0389838218689%
# ratio: 110 : 175 : 228
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 4
# --------------------
# cost=0.21650132536888123
# test cost=0.3271166682243347
# test accurary=87.1345043182373%
# ratio: 35 : 39 : 439
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 5
# --------------------
# cost=0.2665727734565735
# test cost=0.29763340950012207
# test accurary=87.32943534851074%
# ratio: 66 : 35 : 412
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 6
# --------------------
# cost=0.15031768381595612
# test cost=0.2609831690788269
# test accurary=89.08382058143616%
# ratio: 34 : 71 : 408
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 7
# --------------------
# cost=0.31131261587142944
# test cost=0.5422750115394592
# test accurary=78.75243425369263%
# ratio: 46 : 128 : 339
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 8
# --------------------
# cost=0.1243264228105545
# test cost=0.2814689576625824
# test accurary=88.30409646034241%
# ratio: 57 : 73 : 383
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 9
# --------------------
# cost=0.18909631669521332
# test cost=0.7332979440689087
# test accurary=67.83626079559326%
# ratio: 83 : 154 : 276
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 10
# --------------------
# cost=0.247450053691864
# test cost=0.25155752897262573
# test accurary=91.42300486564636%
# ratio: 62 : 35 : 416
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 11
# --------------------
# cost=0.24648676812648773
# test cost=0.3107318878173828
# test accurary=88.49902749061584%
# ratio: 46 : 85 : 382
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 12
# --------------------
# cost=0.005521911662071943
# test cost=0.22941312193870544
# test accurary=93.37232112884521%
# ratio: 47 : 51 : 415
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 13
# --------------------
# cost=0.9760955572128296
# test cost=1.5366227626800537
# test accurary=85.76998114585876%
# ratio: 31 : 2 : 480
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 14
# --------------------
# cost=0.05648767575621605
# test cost=0.4037996530532837
# test accurary=84.7953200340271%
# ratio: 52 : 98 : 363
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 15
# --------------------
# cost=0.16100670397281647
# test cost=0.23751072585582733
# test accurary=91.6179358959198%
# ratio: 43 : 30 : 440
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 16
# --------------------
# cost=0.015209565870463848
# test cost=0.2546181380748749
# test accurary=90.25341272354126%
# ratio: 58 : 66 : 389
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 17
# --------------------
# cost=0.004172490444034338
# test cost=0.20634126663208008
# test accurary=93.95711421966553%
# ratio: 44 : 47 : 422
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 18
# --------------------
# cost=0.18324241042137146
# test cost=0.276931494474411
# test accurary=90.64327478408813%
# ratio: 51 : 65 : 397
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 19
# --------------------
# cost=0.9686548113822937
# test cost=0.19355423748493195
# test accurary=93.56725215911865%
# ratio: 45 : 50 : 418
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 20
# --------------------
# cost=0.04212029278278351
# test cost=0.2804076373577118
# test accurary=90.4483437538147%
# ratio: 35 : 65 : 413
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 21
# --------------------
# cost=0.044171154499053955
# test cost=0.22298428416252136
# test accurary=93.76218318939209%
# ratio: 48 : 49 : 416
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 22
# --------------------
# cost=0.030526120215654373
# test cost=0.2318066954612732
# test accurary=92.59259104728699%
# ratio: 44 : 43 : 426
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 23
# --------------------
# cost=0.015008410438895226
# test cost=0.2922039330005646
# test accurary=91.03313684463501%
# ratio: 44 : 70 : 399
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 24
# --------------------
# cost=0.0017182240262627602
# test cost=0.21219265460968018
# test accurary=93.76218318939209%
# ratio: 46 : 46 : 421
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 25
# --------------------
# cost=0.005471357610076666
# test cost=0.20346076786518097
# test accurary=94.93177533149719%
# ratio: 40 : 46 : 427
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 26
# --------------------
# cost=0.001326071796938777
# test cost=0.2118089199066162
# test accurary=94.15204524993896%
# ratio: 46 : 52 : 415
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 27
# --------------------
# cost=0.0003081493196077645
# test cost=0.21591131389141083
# test accurary=95.12670636177063%
# ratio: 41 : 46 : 426
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 28
# --------------------
# cost=0.009757735766470432
# test cost=0.2105584442615509
# test accurary=94.3469762802124%
# ratio: 42 : 49 : 422
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 29
# --------------------
# cost=0.03210429102182388
# test cost=0.21747316420078278
# test accurary=94.54191327095032%
# ratio: 45 : 47 : 421
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 30
# --------------------
# cost=0.00768382428213954
# test cost=0.268955260515213
# test accurary=93.95711421966553%
# ratio: 44 : 41 : 428
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 31
# --------------------
# cost=0.0010716862743720412
# test cost=0.23294509947299957
# test accurary=93.95711421966553%
# ratio: 44 : 47 : 422
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 32
# --------------------
# cost=2.219242560386192e-05
# test cost=0.23392078280448914
# test accurary=94.54191327095032%
# ratio: 43 : 45 : 425
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 33
# --------------------
# cost=3.490542803774588e-05
# test cost=0.2577842175960541
# test accurary=94.93177533149719%
# ratio: 40 : 42 : 431
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 34
# --------------------
# cost=6.981202750466764e-05
# test cost=0.2315811812877655
# test accurary=94.15204524993896%
# ratio: 43 : 51 : 419
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 35
# --------------------
# cost=0.0004319227300584316
# test cost=0.22694581747055054
# test accurary=94.73684430122375%
# ratio: 37 : 50 : 426
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 36
# --------------------
# cost=0.0006514036795124412
# test cost=0.23907259106636047
# test accurary=94.54191327095032%
# ratio: 42 : 55 : 416
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 37
# --------------------
# cost=0.046887170523405075
# test cost=0.24340897798538208
# test accurary=95.32163739204407%
# ratio: 37 : 45 : 431
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 38
# --------------------
# cost=0.003435710445046425
# test cost=0.32482093572616577
# test accurary=93.37232112884521%
# ratio: 41 : 45 : 427
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 39
# --------------------
# cost=0.0016540950164198875
# test cost=0.25419026613235474
# test accurary=93.95711421966553%
# ratio: 33 : 47 : 433
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 40
# --------------------
# cost=0.6047149896621704
# test cost=1.5438305139541626
# test accurary=69.98050808906555%
# ratio: 57 : 173 : 283
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 41
# --------------------
# cost=0.31413644552230835
# test cost=0.3236701786518097
# test accurary=86.54971122741699%
# ratio: 26 : 89 : 398
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 42
# --------------------
# cost=0.13276423513889313
# test cost=0.3287043571472168
# test accurary=91.81286692619324%
# ratio: 28 : 48 : 437
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 43
# --------------------
# cost=0.10261984914541245
# test cost=0.22019436955451965
# test accurary=93.17739009857178%
# ratio: 45 : 29 : 439
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 44
# --------------------
# cost=0.4310765862464905
# test cost=0.2869124114513397
# test accurary=91.03313684463501%
# ratio: 55 : 57 : 401
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 45
# --------------------
# cost=0.03390435501933098
# test cost=0.42172086238861084
# test accurary=85.9649121761322%
# ratio: 56 : 86 : 371
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 46
# --------------------
# cost=0.08252263069152832
# test cost=0.344955176115036
# test accurary=88.88888955116272%
# ratio: 62 : 36 : 415
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 47
# --------------------
# cost=0.0017968546599149704
# test cost=0.20053578913211823
# test accurary=94.93177533149719%
# ratio: 41 : 43 : 429
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 48
# --------------------
# cost=0.012545755133032799
# test cost=0.23276931047439575
# test accurary=92.7875280380249%
# ratio: 53 : 47 : 413
# --------------------
# EarlyStopping counter: 11 out of 30
# epoch 49
# --------------------
# cost=5.303571742842905e-05
# test cost=0.2080598771572113
# test accurary=94.73684430122375%
# ratio: 35 : 52 : 426
# --------------------
# EarlyStopping counter: 12 out of 30
# epoch 50
# --------------------
# cost=0.000332237861584872
# test cost=0.20821905136108398
# test accurary=94.93177533149719%
# ratio: 36 : 48 : 429
# --------------------
# EarlyStopping counter: 13 out of 30
# epoch 51
# --------------------
# cost=0.006838207598775625
# test cost=0.20671771466732025
# test accurary=94.54191327095032%
# ratio: 38 : 48 : 427
# --------------------
# EarlyStopping counter: 14 out of 30
# epoch 52
# --------------------
# cost=0.0005232899566181004
# test cost=0.20818832516670227
# test accurary=94.93177533149719%
# ratio: 35 : 53 : 425
# --------------------
# EarlyStopping counter: 15 out of 30
# epoch 53
# --------------------
# cost=0.00116479373537004
# test cost=0.2181502729654312
# test accurary=95.12670636177063%
# ratio: 35 : 48 : 430
# --------------------
# EarlyStopping counter: 16 out of 30
# epoch 54
# --------------------
# cost=0.029015734791755676
# test cost=0.22015272080898285
# test accurary=94.3469762802124%
# ratio: 35 : 54 : 424
# --------------------
# EarlyStopping counter: 17 out of 30
# epoch 55
# --------------------
# cost=0.009147187694907188
# test cost=0.24810245633125305
# test accurary=93.37232112884521%
# ratio: 48 : 60 : 405
# --------------------
# EarlyStopping counter: 18 out of 30
# epoch 56
# --------------------
# cost=0.010867098346352577
# test cost=0.2948172986507416
# test accurary=94.3469762802124%
# ratio: 37 : 32 : 444
# --------------------
# EarlyStopping counter: 19 out of 30
# epoch 57
# --------------------
# cost=0.00023008219432085752
# test cost=0.21806780993938446
# test accurary=95.32163739204407%
# ratio: 39 : 47 : 427
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 58
# --------------------
# cost=0.0022634759079664946
# test cost=0.27006933093070984
# test accurary=94.3469762802124%
# ratio: 41 : 34 : 438
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 59
# --------------------
# cost=0.000794301915448159
# test cost=0.22696678340435028
# test accurary=95.12670636177063%
# ratio: 37 : 42 : 434
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 60
# --------------------
# cost=0.01824495568871498
# test cost=0.21855995059013367
# test accurary=95.32163739204407%
# ratio: 38 : 48 : 427
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 61
# --------------------
# cost=6.03292828600388e-05
# test cost=0.22635111212730408
# test accurary=94.73684430122375%
# ratio: 39 : 42 : 432
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 62
# --------------------
# cost=0.004306956194341183
# test cost=0.22562865912914276
# test accurary=95.32163739204407%
# ratio: 38 : 46 : 429
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 63
# --------------------
# cost=1.5456747860298492e-05
# test cost=0.22247125208377838
# test accurary=95.71149945259094%
# ratio: 41 : 45 : 427
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 64
# --------------------
# cost=1.755215816956479e-05
# test cost=0.2239781767129898
# test accurary=95.5165684223175%
# ratio: 37 : 46 : 430
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 65
# --------------------
# cost=7.475702295778319e-05
# test cost=0.21661065518856049
# test accurary=95.71149945259094%
# ratio: 42 : 46 : 425
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 66
# --------------------
# cost=3.914887929568067e-05
# test cost=0.2334168255329132
# test accurary=94.93177533149719%
# ratio: 37 : 41 : 435
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 67
# --------------------
# cost=3.4797878470271826e-05
# test cost=0.23007750511169434
# test accurary=94.93177533149719%
# ratio: 38 : 42 : 433
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 68
# --------------------
# cost=9.461762238061056e-05
# test cost=0.23826324939727783
# test accurary=95.12670636177063%
# ratio: 37 : 42 : 434
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 69
# --------------------
# cost=1.7999595002038404e-05
# test cost=0.22638094425201416
# test accurary=95.32163739204407%
# ratio: 37 : 45 : 431
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 70
# --------------------
# cost=9.579397010384127e-05
# test cost=0.2259046733379364
# test accurary=95.32163739204407%
# ratio: 37 : 45 : 431
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 71
# --------------------
# cost=5.599881842499599e-05
# test cost=0.22054974734783173
# test accurary=95.71149945259094%
# ratio: 38 : 46 : 429
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 72
# --------------------
# cost=0.0001676480023888871
# test cost=0.22547748684883118
# test accurary=95.32163739204407%
# ratio: 37 : 45 : 431
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 73
# --------------------
# cost=0.00181772920768708
# test cost=0.22852496802806854
# test accurary=95.71149945259094%
# ratio: 36 : 46 : 431
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 74
# --------------------
# cost=0.00011282265040790662
# test cost=0.22699254751205444
# test accurary=95.71149945259094%
# ratio: 37 : 45 : 431
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 75
# --------------------
# cost=6.431282236007974e-05
# test cost=0.2201184630393982
# test accurary=95.71149945259094%
# ratio: 38 : 46 : 429
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 76
# --------------------
# cost=0.0007933297893032432
# test cost=0.2239232063293457
# test accurary=95.90643644332886%
# ratio: 43 : 46 : 424
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 77
# --------------------
# cost=0.0006861846195533872
# test cost=0.2200860232114792
# test accurary=95.90643644332886%
# ratio: 41 : 46 : 426
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 78
# --------------------
# cost=5.6927729019662365e-05
# test cost=0.22877931594848633
# test accurary=95.12670636177063%
# ratio: 37 : 44 : 432
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 79
# --------------------
# cost=6.596195362362778e-06
# test cost=0.2216900885105133
# test accurary=95.5165684223175%
# ratio: 39 : 46 : 428
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 80
# --------------------
# cost=0.0014973509823903441
# test cost=0.23442453145980835
# test accurary=95.32163739204407%
# ratio: 36 : 44 : 433
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 81
# --------------------
# cost=0.00022464661742560565
# test cost=0.2294105887413025
# test accurary=95.71149945259094%
# ratio: 36 : 46 : 431
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 82
# --------------------
# cost=9.06947570911143e-06
# test cost=0.22638656198978424
# test accurary=95.71149945259094%
# ratio: 38 : 46 : 429
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 83
# --------------------
# cost=0.00040357711259275675
# test cost=0.23835858702659607
# test accurary=95.5165684223175%
# ratio: 37 : 42 : 434
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 84
# --------------------
# cost=0.00033685972448438406
# test cost=0.2384432554244995
# test accurary=95.5165684223175%
# ratio: 36 : 41 : 436
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 85
# --------------------
# cost=8.927728049457073e-05
# test cost=0.22617702186107635
# test accurary=95.5165684223175%
# ratio: 38 : 47 : 428
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 86
# --------------------
# cost=3.164696681778878e-05
# test cost=0.2283097505569458
# test accurary=95.5165684223175%
# ratio: 38 : 47 : 428
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 87
# --------------------
# cost=0.000193167055840604
# test cost=0.22049151360988617
# test accurary=95.71149945259094%
# ratio: 41 : 47 : 425
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 88
# --------------------
# cost=7.420690963044763e-06
# test cost=0.22309647500514984
# test accurary=95.5165684223175%
# ratio: 40 : 47 : 426
# --------------------
# EarlyStopping counter: 11 out of 30
# epoch 89
# --------------------
# cost=0.06664111465215683
# test cost=0.24091725051403046
# test accurary=95.90643644332886%
# ratio: 39 : 47 : 427
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 90
# --------------------
# cost=2.7480905055999756
# test cost=1.3349761962890625
# test accurary=83.62573385238647%
# ratio: 6 : 70 : 437
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 91
# --------------------
# cost=0.2923015356063843
# test cost=0.5125983357429504
# test accurary=77.582848072052%
# ratio: 89 : 101 : 323
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 92
# --------------------
# cost=0.18561556935310364
# test cost=1.492201328277588
# test accurary=61.79337501525879%
# ratio: 58 : 213 : 242
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 93
# --------------------
# cost=0.08461590111255646
# test cost=0.3676280677318573
# test accurary=88.30409646034241%
# ratio: 70 : 47 : 396
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 94
# --------------------
# cost=0.013688458129763603
# test cost=0.27535155415534973
# test accurary=91.22806787490845%
# ratio: 57 : 57 : 399
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 95
# --------------------
# cost=0.02175195887684822
# test cost=0.9346699714660645
# test accurary=76.02339386940002%
# ratio: 36 : 160 : 317
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 96
# --------------------
# cost=0.1921907514333725
# test cost=0.3615071177482605
# test accurary=90.4483437538147%
# ratio: 52 : 33 : 428
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 97
# --------------------
# cost=0.0008794806199148297
# test cost=0.21404524147510529
# test accurary=95.12670636177063%
# ratio: 32 : 43 : 438
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 98
# --------------------
# cost=0.00043111969716846943
# test cost=0.196399986743927
# test accurary=94.73684430122375%
# ratio: 46 : 52 : 415
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 99
# --------------------
# cost=0.003880324773490429
# test cost=0.2602371275424957
# test accurary=93.37232112884521%
# ratio: 34 : 57 : 422
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 100
# --------------------
# cost=0.0006545867072418332
# test cost=0.279684841632843
# test accurary=92.7875280380249%
# ratio: 47 : 57 : 409
# --------------------
# EarlyStopping counter: 11 out of 30
# epoch 101
# --------------------
# cost=0.005958012770861387
# test cost=0.24022440612316132
# test accurary=94.3469762802124%
# ratio: 46 : 49 : 418
# --------------------
# EarlyStopping counter: 12 out of 30
# epoch 102
# --------------------
# cost=0.0023693114053457975
# test cost=0.2396954447031021
# test accurary=94.73684430122375%
# ratio: 42 : 49 : 422
# --------------------
# EarlyStopping counter: 13 out of 30
# epoch 103
# --------------------
# cost=0.0005571490619331598
# test cost=0.2509400248527527
# test accurary=94.54191327095032%
# ratio: 40 : 44 : 429
# --------------------
# EarlyStopping counter: 14 out of 30
# epoch 104
# --------------------
# cost=0.0018206262029707432
# test cost=0.2492062747478485
# test accurary=94.3469762802124%
# ratio: 41 : 48 : 424
# --------------------
# EarlyStopping counter: 15 out of 30
# epoch 105
# --------------------
# cost=0.002354746451601386
# test cost=0.2480771839618683
# test accurary=95.32163739204407%
# ratio: 40 : 52 : 421
# --------------------
# EarlyStopping counter: 16 out of 30
# epoch 106
# --------------------
# cost=0.0001860639895312488
# test cost=0.24539433419704437
# test accurary=95.12670636177063%
# ratio: 40 : 51 : 422
# --------------------
# EarlyStopping counter: 17 out of 30
# epoch 107
# --------------------
# cost=0.0004236297099851072
# test cost=0.2439967393875122
# test accurary=94.93177533149719%
# ratio: 40 : 50 : 423
# --------------------
# EarlyStopping counter: 18 out of 30
# epoch 108
# --------------------
# cost=0.0003223932289984077
# test cost=0.25619301199913025
# test accurary=94.93177533149719%
# ratio: 41 : 49 : 423
# --------------------
# EarlyStopping counter: 19 out of 30
# epoch 109
# --------------------
# cost=0.0013284230371937156
# test cost=0.2536318302154541
# test accurary=94.93177533149719%
# ratio: 41 : 51 : 421
# --------------------
# EarlyStopping counter: 20 out of 30
# epoch 110
# --------------------
# cost=0.0008885375573299825
# test cost=0.2558663487434387
# test accurary=94.93177533149719%
# ratio: 41 : 49 : 423
# --------------------
# EarlyStopping counter: 21 out of 30
# epoch 111
# --------------------
# cost=8.284964133054018e-05
# test cost=0.2693120241165161
# test accurary=94.93177533149719%
# ratio: 40 : 56 : 417
# --------------------
# EarlyStopping counter: 22 out of 30
# epoch 112
# --------------------
# cost=4.708724191004876e-06
# test cost=0.2576628625392914
# test accurary=95.32163739204407%
# ratio: 40 : 50 : 423
# --------------------
# EarlyStopping counter: 23 out of 30
# epoch 113
# --------------------
# cost=0.00011907113366760314
# test cost=0.26033085584640503
# test accurary=95.12670636177063%
# ratio: 39 : 52 : 422
# --------------------
# EarlyStopping counter: 24 out of 30
# epoch 114
# --------------------
# cost=0.0012160763144493103
# test cost=0.26103973388671875
# test accurary=94.93177533149719%
# ratio: 38 : 50 : 425
# --------------------
# EarlyStopping counter: 25 out of 30
# epoch 115
# --------------------
# cost=2.47534153459128e-05
# test cost=0.25938984751701355
# test accurary=95.12670636177063%
# ratio: 40 : 53 : 420
# --------------------
# EarlyStopping counter: 26 out of 30
# epoch 116
# --------------------
# cost=0.23639950156211853
# test cost=0.3075108230113983
# test accurary=93.56725215911865%
# ratio: 54 : 49 : 410
# --------------------
# ...
# epoch 108
# --------------------
# cost=0.00020992317877244204
# test cost=0.2511788010597229
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 109
# --------------------
# cost=0.000593713775742799
# test cost=0.30551666021347046
# test accurary=93.76218318939209%
# ratio: 31 : 31 : 451
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 110
# --------------------
# cost=0.00019976442854385823
# test cost=0.23733116686344147
# test accurary=94.93177533149719%
# ratio: 32 : 40 : 441
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 111
# --------------------
# cost=0.0002255561266792938
# test cost=0.24524173140525818
# test accurary=94.93177533149719%
# ratio: 32 : 38 : 443
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 112
# --------------------
# cost=9.319677337771282e-05
# test cost=0.26119592785835266
# test accurary=94.54191327095032%
# ratio: 31 : 37 : 445
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 113
# --------------------
# cost=9.421916911378503e-05
# test cost=0.27527979016304016
# test accurary=94.3469762802124%
# ratio: 30 : 37 : 446
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 114
# --------------------
# cost=0.00018170902330894023
# test cost=0.27251020073890686
# test accurary=94.3469762802124%
# ratio: 31 : 36 : 446
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 115
# --------------------
# cost=0.00018268627172801644
# test cost=0.2552936375141144
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 116
# --------------------
# cost=0.00017045109416358173
# test cost=0.2458305060863495
# test accurary=94.73684430122375%
# ratio: 31 : 38 : 444
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 117
# --------------------
# cost=9.290512389270589e-05
# test cost=0.2623938322067261
# test accurary=94.54191327095032%
# ratio: 31 : 37 : 445
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 118
# --------------------
# cost=0.0001713600941002369
# test cost=0.2663411796092987
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 119
# --------------------
# cost=0.00015437390538863838
# test cost=0.28116360306739807
# test accurary=94.54191327095032%
# ratio: 31 : 37 : 445
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 120
# --------------------
# cost=0.00033898436231538653
# test cost=0.28094398975372314
# test accurary=94.3469762802124%
# ratio: 31 : 36 : 446
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 121
# --------------------
# cost=6.911788659635931e-05
# test cost=0.24362529814243317
# test accurary=94.93177533149719%
# ratio: 32 : 38 : 443
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 122
# --------------------
# cost=9.07646244741045e-05
# test cost=0.2792886793613434
# test accurary=94.54191327095032%
# ratio: 31 : 37 : 445
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 123
# --------------------
# cost=0.00010067361290566623
# test cost=0.25398769974708557
# test accurary=94.93177533149719%
# ratio: 32 : 38 : 443
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 124
# --------------------
# cost=0.00010283081792294979
# test cost=0.26725584268569946
# test accurary=94.54191327095032%
# ratio: 31 : 37 : 445
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 125
# --------------------
# cost=0.00010938510240521282
# test cost=0.25736203789711
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 126
# --------------------
# cost=9.476092964177951e-05
# test cost=0.2529105246067047
# test accurary=94.73684430122375%
# ratio: 31 : 38 : 444
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 127
# --------------------
# cost=0.0002137936098733917
# test cost=0.26493915915489197
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 128
# --------------------
# cost=0.0006304475828073919
# test cost=0.27401021122932434
# test accurary=94.3469762802124%
# ratio: 31 : 36 : 446
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 129
# --------------------
# cost=0.00021390117763075978
# test cost=0.24078072607517242
# test accurary=94.15204524993896%
# ratio: 38 : 38 : 437
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 130
# --------------------
# cost=0.00011769212869694456
# test cost=0.2924416661262512
# test accurary=93.76218318939209%
# ratio: 31 : 33 : 449
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 131
# --------------------
# cost=0.00015941417950671166
# test cost=0.26470115780830383
# test accurary=94.54191327095032%
# ratio: 32 : 36 : 445
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 132
# --------------------
# cost=0.0001376112923026085
# test cost=0.27420133352279663
# test accurary=94.54191327095032%
# ratio: 31 : 37 : 445
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 133
# --------------------
# cost=9.219662024406716e-05
# test cost=0.27842697501182556
# test accurary=94.73684430122375%
# ratio: 32 : 37 : 444
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 134
# --------------------
# cost=9.596463496563956e-05
# test cost=0.254235178232193
# test accurary=94.93177533149719%
# ratio: 32 : 38 : 443
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 135
# --------------------
# cost=7.208200986497104e-05
# test cost=0.27900803089141846
# test accurary=94.54191327095032%
# ratio: 31 : 37 : 445
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 136
# --------------------
# cost=5.7928064052248374e-05
# test cost=0.2388514131307602
# test accurary=94.93177533149719%
# ratio: 32 : 38 : 443
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 137
# --------------------
# cost=0.00012541189789772034
# test cost=0.29084935784339905
# test accurary=94.3469762802124%
# ratio: 31 : 36 : 446
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 138
# --------------------
# cost=0.003935448359698057
# test cost=0.43548500537872314
# test accurary=92.59259104728699%
# ratio: 28 : 26 : 459
# --------------------
# EarlyStopping counter: 2 out of 30
# epoch 139
# --------------------
# cost=1.3907039165496826
# test cost=0.9573317170143127
# test accurary=79.72709536552429%
# ratio: 4 : 72 : 437
# --------------------
# EarlyStopping counter: 3 out of 30
# epoch 140
# --------------------
# cost=0.8618656992912292
# test cost=1.02206289768219
# test accurary=68.61598491668701%
# ratio: 178 : 19 : 316
# --------------------
# EarlyStopping counter: 4 out of 30
# epoch 141
# --------------------
# cost=0.4342021644115448
# test cost=0.24785205721855164
# test accurary=92.00779795646667%
# ratio: 36 : 52 : 425
# --------------------
# EarlyStopping counter: 5 out of 30
# epoch 142
# --------------------
# cost=0.24902036786079407
# test cost=0.3610438406467438
# test accurary=86.35477423667908%
# ratio: 80 : 43 : 390
# --------------------
# EarlyStopping counter: 6 out of 30
# epoch 143
# --------------------
# cost=0.17311935126781464
# test cost=0.2326531857252121
# test accurary=92.00779795646667%
# ratio: 46 : 43 : 424
# --------------------
# EarlyStopping counter: 7 out of 30
# epoch 144
# --------------------
# cost=0.011712505482137203
# test cost=0.2573407292366028
# test accurary=92.39766001701355%
# ratio: 37 : 36 : 440
# --------------------
# EarlyStopping counter: 8 out of 30
# epoch 145
# --------------------
# cost=0.003944591153413057
# test cost=0.23877955973148346
# test accurary=92.39766001701355%
# ratio: 39 : 44 : 430
# --------------------
# EarlyStopping counter: 9 out of 30
# epoch 146
# --------------------
# cost=0.004731354303658009
# test cost=0.2415306270122528
# test accurary=92.98245906829834%
# ratio: 37 : 35 : 441
# --------------------
# EarlyStopping counter: 10 out of 30
# epoch 147
# --------------------
# cost=0.016180872917175293
# test cost=0.24524585902690887
# test accurary=93.76218318939209%
# ratio: 36 : 38 : 439
# --------------------
# EarlyStopping counter: 11 out of 30
# epoch 148
# --------------------
# cost=0.003927464131265879
# test cost=0.2410665601491928
# test accurary=93.56725215911865%
# ratio: 36 : 39 : 438
# --------------------
# EarlyStopping counter: 12 out of 30
# epoch 149
# --------------------
# cost=0.0038254682440310717
# test cost=0.25338214635849
# test accurary=93.17739009857178%
# ratio: 36 : 35 : 442
# --------------------
# EarlyStopping counter: 13 out of 30
# epoch 150
# --------------------
# cost=0.007198737468570471
# test cost=0.25925278663635254
# test accurary=92.98245906829834%
# ratio: 35 : 35 : 443
# --------------------
# EarlyStopping counter: 14 out of 30
# epoch 151
# --------------------
# cost=0.003753643250092864
# test cost=0.24555924534797668
# test accurary=93.56725215911865%
# ratio: 37 : 38 : 438
# --------------------
# EarlyStopping counter: 15 out of 30
# epoch 152
# --------------------
# cost=0.013058247976005077
# test cost=0.258053719997406
# test accurary=93.56725215911865%
# ratio: 36 : 37 : 440
# --------------------
# EarlyStopping counter: 16 out of 30
# epoch 153
# --------------------
# cost=0.0012748031876981258
# test cost=0.2507763206958771
# test accurary=93.56725215911865%
# ratio: 37 : 38 : 438
# --------------------
# EarlyStopping counter: 17 out of 30
# epoch 154
# --------------------
# cost=0.008742045611143112
# test cost=0.2641303241252899
# test accurary=93.56725215911865%
# ratio: 34 : 37 : 442
# --------------------
# EarlyStopping counter: 18 out of 30
# epoch 155
# --------------------
# cost=0.0028539395425468683
# test cost=0.26887014508247375
# test accurary=93.37232112884521%
# ratio: 34 : 36 : 443
# --------------------
# EarlyStopping counter: 19 out of 30
# epoch 156
# --------------------
# cost=0.0024435180239379406
# test cost=0.2628466784954071
# test accurary=93.95711421966553%
# ratio: 35 : 38 : 440
# --------------------
# EarlyStopping counter: 20 out of 30
# epoch 157
# --------------------
# cost=0.0012178891338407993
# test cost=0.2766943871974945
# test accurary=93.56725215911865%
# ratio: 34 : 37 : 442
# --------------------
# EarlyStopping counter: 21 out of 30
# epoch 158
# --------------------
# cost=0.0017316552111878991
# test cost=0.26842695474624634
# test accurary=93.76218318939209%
# ratio: 35 : 37 : 441
# --------------------
# EarlyStopping counter: 22 out of 30
# epoch 159
# --------------------
# cost=0.0007164114504121244
# test cost=0.26715317368507385
# test accurary=93.37232112884521%
# ratio: 37 : 37 : 439
# --------------------
# EarlyStopping counter: 23 out of 30
# epoch 160
# --------------------
# cost=0.0005392389139160514
# test cost=0.2697194814682007
# test accurary=93.56725215911865%
# ratio: 36 : 37 : 440
# --------------------
# EarlyStopping counter: 24 out of 30
# epoch 161
# --------------------
# cost=0.0011955685913562775
# test cost=0.26712384819984436
# test accurary=93.56725215911865%
# ratio: 36 : 37 : 440
# --------------------
# EarlyStopping counter: 25 out of 30
# epoch 162
# --------------------
# cost=0.00037718540988862514
# test cost=0.2716478705406189
# test accurary=93.37232112884521%
# ratio: 35 : 37 : 441
# --------------------
# EarlyStopping counter: 26 out of 30
# epoch 163
# --------------------
# cost=0.0002838958171196282
# test cost=0.2614986002445221
# test accurary=93.56725215911865%
# ratio: 35 : 38 : 440
# --------------------
# EarlyStopping counter: 27 out of 30
# epoch 164
# --------------------
# cost=0.0004928350681439042
# test cost=0.2701095640659332
# test accurary=93.95711421966553%
# ratio: 33 : 38 : 442
# --------------------
# EarlyStopping counter: 28 out of 30
# epoch 165
# --------------------
# cost=0.0010900184279307723
# test cost=0.2712310254573822
# test accurary=93.95711421966553%
# ratio: 33 : 38 : 442
# --------------------
# EarlyStopping counter: 29 out of 30
# epoch 166
# --------------------
# cost=0.0036981329321861267
# test cost=0.2736436128616333
# test accurary=93.95711421966553%
# ratio: 33 : 38 : 442
# --------------------
# EarlyStopping counter: 30 out of 30
# Early stopping, current best acc:0.9688109159469604
# lr: 0.0005334377042933891, batch_size=64
# epoch 1
# --------------------
# cost=1.5243486166000366
# test cost=1.008774757385254
# test accurary=28.849902749061584%
# ratio: 355 : 57 : 101
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 2
# --------------------
# cost=1.4328327178955078
# test cost=0.5763919949531555
# test accurary=80.50682544708252%
# ratio: 74 : 36 : 403
# --------------------
# 점수는 나아졌으나 전체 모델 점수보단 덜함.
# epoch 3
# --------------------
# cost=0.7152155041694641
# test cost=0.9357984066009521
# test accurary=60.0389838218689%
# ratio: 121 : 157 : 235
# --------------------
# EarlyStopping counter: 1 out of 30
# epoch 4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-6470375517fd> in <module>
#      31             y_batch = y_batch.to(device)
#      32             # print(x_batch.size())
# ---> 33             criterion = model(x_batch)
#      34             # print(criterion.size())
#      35             # weight = torch.Tensor([13, 13, 1]).to(device)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-8-ef668e3f3858> in forward(self, x)
#      97
#      98       out = F.relu(self.Block_C_1(out) + self.conv1x1_C(out))
# ---> 99       out = F.relu(self.Block_C_2(out) + out)
#     100       out = F.max_pool1d(out, 3, 2, 1)
#     101
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-8-ef668e3f3858> in forward(self, x)
#      27
#      28     def forward(self, x):
# ---> 29         return self.layer(x)
#      30
#      31 class Block_D(nn.Module):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     177             bn_training,
#     178             exponential_average_factor,
# --> 179             self.eps,
#     180         )
#     181
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2437
#    2438     return torch.batch_norm(
# -> 2439         input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2440     )
#    2441
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.plot(best_train_score, label='train')
plt.plot(best_test_score, label='test')
plt.title('ResNet1d-18 Cost Plot')
plt.xlabel('epoch')
plt.ylabel('cost')
plt.grid()
plt.legend()
plt.show()

# %%
plt.plot(best_test_accuracy, color='orange', label='Test Accuracy')
plt.title('Accuracy')
plt.xlabel('epoch')
plt.ylabel('cost')
plt.grid()
plt.legend()
plt.show()

# %%
best_model = Resnet1d()
best_model_dict = torch.load('checkpoint_9688.pt')
best_model.load_state_dict(best_model_dict)
torch.save(best_model, 'resnet1d_9688.pt')

# %%
# 최상의 모델 평가
torch.cuda.empty_cache()
best_model
best_model.eval()

best_criterion = best_model(X_test.unsqueeze(1))
best_criterion
acc = sum(best_criterion.argmax(dim=1) == Y_test.argmax(dim=1)).item() / Y_test.shape[0]
print(f'test accurary: {100*acc}%')
print(Y_test.shape[0])
print(best_criterion.argmax(dim=1))
print(Y_test.argmax(dim=1))
for i in range(3):
    print(f'{i}번 label')
    print(f'실제: {(Y_test.argmax(dim=1) == i).sum()}개')
    print(f'예측: {(best_criterion.argmax(dim=1) == i).sum()}개')
# Out:
# test accurary: 96.88109161793372%
# 513
# tensor([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 1, 2, 2, 1,
#         1, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2,
#         0, 0, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 2, 1, 2,
#         2, 2, 2, 2, 0, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 0, 2, 0, 1, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2,
#         2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 1, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 1,
#         2, 1, 0, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 0, 2, 2, 2, 1, 0, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#         2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1,
#         2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 0,
#         1, 2, 2, 2, 1, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 0, 2, 2, 2,
#         2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 0, 2, 2, 1, 0,
#         2, 2, 0, 0, 2, 2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#         2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2,
#         2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 1, 2, 0,
#         2, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2,
#         0, 2, 2, 2, 2, 0, 2, 1, 2])
# tensor([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 1, 2, 2, 1,
#         1, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 0, 1, 1, 2, 2,
#         0, 0, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 0, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 2, 1, 2,
#         2, 2, 2, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 0, 2, 0, 1, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2,
#         2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 0, 2, 2, 1, 2, 2,
#         2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 1,
#         2, 1, 0, 2, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 2, 2, 2, 1, 1, 0, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#         2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 1, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#         1, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1,
#         2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 0, 0,
#         1, 2, 2, 2, 1, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 0, 2, 2, 2,
#         2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 0, 2, 2, 1, 0,
#         2, 2, 0, 0, 2, 2, 2, 1, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0,
#         2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2,
#         2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 1, 2, 2, 2, 2, 1, 2, 0,
#         1, 0, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 2,
#         2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 1, 2, 2, 1, 2,
#         2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2, 2, 2, 2, 0, 2, 2, 2,
#         0, 2, 2, 2, 0, 0, 2, 1, 2])
# 0번 label
# 실제: 44개
# 예측: 40개
# 1번 label
# 실제: 48개
# 예측: 42개
# 2번 label
# 실제: 421개
# 예측: 431개

# %%
a = best_criterion.argmax(dim=1)
b = Y_test.argmax(dim=1)

L = [[0, 0, 0], [0, 0, 0], [0, 0, 0]]  # 첫 인덱스는 x, 다음 인덱스는 y
for i, j in zip(a, b):
  L[i][j] += 1  # [예측][실제]
print(L)

L = list((100 * np.array(L) / 513).round(2))

import seaborn as sns
L2 = [[79, 3],
      [13, 418]]
sns.heatmap(L2, annot=True, fmt='d', cmap='Blues')
# Out:
# [[38, 0, 2], [0, 41, 1], [6, 7, 418]]
